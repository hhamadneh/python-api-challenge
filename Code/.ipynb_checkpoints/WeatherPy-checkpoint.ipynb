# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import json


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List¶

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %% [markdown]
# # Perform API Calls¶
# #Perform a weather check on each city using a series of successive API calls.
# #Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Get the Weather data
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={api_key}&units={units}&q="

weather_response = requests.get(query_url + city)
weather_json = weather_response.json()

#print(json.dumps(weather_json, indent=4))
#print(requests.get(query_url+city))

# Set Up Lists to Hold Reponse Info
city_name = []
latitude= []
longitude = []
max_temperature = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

# Processing Record Counter Starting a 1
processing_record = 1

# Print Starting Log Statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Loop Through List of Cities & Perform a Request for Data on Each
for city in cities:
   
     
# Exception Handling
    try:
        response = requests.get(query_url+ city).json()
        city_name.append(response["name"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temperature.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(pd.to_datetime(response["dt"],unit='s'))
        current_city = response["name"]
        print(f"Processing Record {processing_record}| {current_city}")
    
        # Increase Processing Record Counter by 1 For Each Loop
        processing_record += 1
          
    except:
        print("City not found next ...") 
    continue

# Print Ending Log Statement
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1| Saskylakh
# Processing Record 2| Casa Nova
# Processing Record 3| Tuktoyaktuk
# Processing Record 4| Bud
# Processing Record 5| Mbabane
# Processing Record 6| Nishihara
# Processing Record 7| Bonavista
# Processing Record 8| Ungaran
# Processing Record 9| Rikitea
# Processing Record 10| Kapaa
# Processing Record 11| Kaitangata
# Processing Record 12| Dongli
# Processing Record 13| Tasiilaq
# Processing Record 14| Port Alfred
# Processing Record 15| Albany
# Processing Record 16| San Patricio
# Processing Record 17| Cape Town
# Processing Record 18| Laguna
# Processing Record 19| Busselton
# Processing Record 20| Lavrentiya
# Processing Record 21| Buta
# Processing Record 22| Caucaia
# Processing Record 23| Iqaluit
# Processing Record 24| Saint Paul Harbor
# Processing Record 25| Kadaň
# Processing Record 26| Nizhnyaya Tavda
# Processing Record 27| Lianzhou
# Processing Record 28| Bunia
# Processing Record 29| New Norfolk
# Processing Record 30| Hermanus
# Processing Record 31| Navahrudak
# Processing Record 32| Princeton
# Processing Record 33| Eyl
# City not found next ...
# Processing Record 34| Avera
# Processing Record 35| Egvekinot
# Processing Record 36| Malaṅgawā
# Processing Record 37| Nome
# Processing Record 38| Naryan-Mar
# Processing Record 39| Mahébourg
# Processing Record 40| Bluff
# Processing Record 41| Mataura
# Processing Record 42| Ushuaia
# Processing Record 43| Alofi
# Processing Record 44| Hede
# Processing Record 45| Barrow
# Processing Record 46| Sawākin
# Processing Record 47| Bengkulu
# Processing Record 48| San Pedro de Macorís
# City not found next ...
# Processing Record 49| Bethel
# Processing Record 50| Along
# Processing Record 51| Ugoofaaru
# Processing Record 52| Jamestown
# Processing Record 53| Kavieng
# Processing Record 54| Ponta do Sol
# City not found next ...
# Processing Record 55| Yellowknife
# Processing Record 56| Bredasdorp
# Processing Record 57| Guerrero Negro
# Processing Record 58| Pacific Grove
# Processing Record 59| Mackenzie
# Processing Record 60| Glendive
# Processing Record 61| Beidao
# Processing Record 62| Muravlenko
# Processing Record 63| Arraial do Cabo
# Processing Record 64| Khovd
# Processing Record 65| Florence
# Processing Record 66| Punta Arenas
# Processing Record 67| Avarua
# Processing Record 68| Thompson
# City not found next ...
# Processing Record 69| Yarkovo
# Processing Record 70| Qeshm
# Processing Record 71| Kushima
# Processing Record 72| Piaçabuçu
# City not found next ...
# Processing Record 73| Fare
# City not found next ...
# Processing Record 74| Chumikan
# Processing Record 75| Faanui
# Processing Record 76| Severo-Kuril'sk
# Processing Record 77| Urucará
# Processing Record 78| Chokwé
# Processing Record 79| Atuona
# Processing Record 80| Nouadhibou
# Processing Record 81| Hilo
# Processing Record 82| Hasaki
# Processing Record 83| Necochea
# Processing Record 84| Okhotsk
# Processing Record 85| Port-Gentil
# Processing Record 86| Saint-Pierre
# Processing Record 87| Green River
# City not found next ...
# City not found next ...
# Processing Record 88| San Cristobal
# Processing Record 89| Vestmanna
# Processing Record 90| Tombouctou
# Processing Record 91| Mogadishu
# Processing Record 92| Sobolevo
# City not found next ...
# Processing Record 93| Pandharpur
# Processing Record 94| Wanning
# Processing Record 95| Vaini
# Processing Record 96| Jaguariaíva
# Processing Record 97| Dingle
# Processing Record 98| Nikolskoye
# Processing Record 99| Puerto Ayacucho
# Processing Record 100| Roblin
# Processing Record 101| Mar del Plata
# Processing Record 102| Bay Roberts
# Processing Record 103| Dhidhdhoo
# Processing Record 104| São Filipe
# Processing Record 105| Atikokan
# City not found next ...
# Processing Record 106| Makakilo City
# Processing Record 107| Villazón
# Processing Record 108| Manavālakurichi
# Processing Record 109| Khatanga
# Processing Record 110| Gushikawa
# Processing Record 111| Basco
# Processing Record 112| Dakar
# Processing Record 113| Chokurdakh
# Processing Record 114| Nanortalik
# Processing Record 115| Cayenne
# City not found next ...
# Processing Record 116| Merseburg
# Processing Record 117| Tessalit
# Processing Record 118| Iralaya
# Processing Record 119| City of San Pedro
# Processing Record 120| Clyde River
# Processing Record 121| Airai
# Processing Record 122| Watsa
# Processing Record 123| Tuatapere
# Processing Record 124| Semey
# Processing Record 125| Portland
# Processing Record 126| Rawson
# Processing Record 127| Pangnirtung
# City not found next ...
# Processing Record 128| Lompoc
# Processing Record 129| Upernavik
# Processing Record 130| Loa Janan
# City not found next ...
# Processing Record 131| Ust-Maya
# Processing Record 132| Krasnosel'kup
# Processing Record 133| Hithadhoo
# Processing Record 134| Atambua
# Processing Record 135| George Town
# Processing Record 136| Batagay-Alyta
# Processing Record 137| Saint-François
# Processing Record 138| Guácimo
# City not found next ...
# Processing Record 139| Mariental
# Processing Record 140| Rio do Sul
# Processing Record 141| Lüderitz
# Processing Record 142| Khāsh
# City not found next ...
# Processing Record 143| Gijang
# Processing Record 144| Ilhabela
# Processing Record 145| Dikson
# Processing Record 146| Castro
# Processing Record 147| Tiksi
# Processing Record 148| Karhal
# Processing Record 149| Taoudenni
# Processing Record 150| Weatherford
# City not found next ...
# Processing Record 151| Sedalia
# Processing Record 152| Måløy
# Processing Record 153| Margate
# Processing Record 154| San Quintín
# Processing Record 155| Paamiut
# Processing Record 156| Carupano
# Processing Record 157| Goba
# Processing Record 158| Whitehorse
# Processing Record 159| Spearfish
# Processing Record 160| Cidreira
# Processing Record 161| Tual
# Processing Record 162| Rakaia
# City not found next ...
# Processing Record 163| Butaritari
# Processing Record 164| Karpogory
# Processing Record 165| Fortuna
# Processing Record 166| Kilindoni
# Processing Record 167| Vardø
# Processing Record 168| Nizwá
# Processing Record 169| Haines Junction
# Processing Record 170| Marawi
# Processing Record 171| Diamantino
# Processing Record 172| Katsina
# Processing Record 173| Port Elizabeth
# Processing Record 174| Walvis Bay
# City not found next ...
# City not found next ...
# Processing Record 175| Qaanaaq
# Processing Record 176| Partizanskoye
# Processing Record 177| Kharitonovo
# City not found next ...
# Processing Record 178| Bumba
# Processing Record 179| Hobart
# Processing Record 180| Bambous Virieux
# Processing Record 181| Östersund
# City not found next ...
# Processing Record 182| Sabla
# City not found next ...
# Processing Record 183| Departamento de Maldonado
# Processing Record 184| Buchanan
# Processing Record 185| Kloulklubed
# Processing Record 186| Epe
# Processing Record 187| Honningsvåg
# City not found next ...
# Processing Record 188| Villa María
# Processing Record 189| Chimbote
# Processing Record 190| Verkhnevilyuysk
# Processing Record 191| Torbay
# Processing Record 192| Cherskiy
# Processing Record 193| Isangel
# Processing Record 194| Kondagaon
# Processing Record 195| Palanga
# Processing Record 196| Kattivākkam
# Processing Record 197| Port Lincoln
# Processing Record 198| Fengrun
# City not found next ...
# City not found next ...
# Processing Record 199| Alice Springs
# Processing Record 200| Mwingi
# Processing Record 201| Lakes Entrance
# Processing Record 202| Adrar
# Processing Record 203| Escada
# Processing Record 204| Chui
# Processing Record 205| Mananjary
# Processing Record 206| Abu Kamal
# Processing Record 207| Petropavlovsk-Kamchatskiy
# Processing Record 208| Mount Isa
# Processing Record 209| Ribeira Grande
# Processing Record 210| Santa Cruz de la Sierra
# Processing Record 211| Karratha
# Processing Record 212| Grand Gaube
# Processing Record 213| Pirgos
# Processing Record 214| Chāndil
# Processing Record 215| Tooele
# Processing Record 216| East London
# Processing Record 217| Dilla
# Processing Record 218| Jega
# Processing Record 219| Yining
# Processing Record 220| Vostok
# Processing Record 221| Aldan
# Processing Record 222| Cartagena
# Processing Record 223| Uribia
# Processing Record 224| Novoorsk
# Processing Record 225| Mbekenyera
# Processing Record 226| Sapatgrām
# Processing Record 227| Chāndbāli
# Processing Record 228| Flin Flon
# Processing Record 229| Lerwick
# Processing Record 230| Husavik
# Processing Record 231| North Platte
# Processing Record 232| Pevek
# Processing Record 233| Chermoz
# Processing Record 234| Hong Gai
# Processing Record 235| Mehamn
# Processing Record 236| Sitka
# Processing Record 237| Tutóia
# Processing Record 238| Ayan
# Processing Record 239| Enid
# Processing Record 240| Mossamedes
# Processing Record 241| Bima
# Processing Record 242| Kruisfontein
# Processing Record 243| Batemans Bay
# Processing Record 244| Mīzan Teferī
# Processing Record 245| Ponta Delgada
# Processing Record 246| Cururupu
# Processing Record 247| Owatonna
# Processing Record 248| Longyearbyen
# Processing Record 249| Taseyevo
# Processing Record 250| Nuuk
# Processing Record 251| Vila do Maio
# City not found next ...
# Processing Record 252| Aasiaat
# Processing Record 253| Evensk
# Processing Record 254| Muli
# City not found next ...
# Processing Record 255| Henties Bay
# Processing Record 256| Geraldton
# City not found next ...
# Processing Record 257| Davila
# Processing Record 258| Vanimo
# Processing Record 259| Tadine
# Processing Record 260| Olinda
# Processing Record 261| Talnakh
# City not found next ...
# Processing Record 262| Hearst
# City not found next ...
# Processing Record 263| Desaguadero
# Processing Record 264| Puerto Ayora
# Processing Record 265| Saint-Philippe
# Processing Record 266| Cascais
# City not found next ...
# Processing Record 267| Carnarvon
# Processing Record 268| Kos
# Processing Record 269| Flinders
# Processing Record 270| Vila Velha
# Processing Record 271| Lebu
# Processing Record 272| Beringovskiy
# Processing Record 273| Katsuura
# Processing Record 274| Kahului
# Processing Record 275| Dudinka
# Processing Record 276| Hong Kong
# Processing Record 277| Namtsy
# Processing Record 278| Takoradze
# Processing Record 279| Esperance
# Processing Record 280| Bumbuna
# Processing Record 281| Port Hedland
# Processing Record 282| Olafsvik
# Processing Record 283| Turaif
# Processing Record 284| Carauari
# Processing Record 285| Kulhudhuffushi
# Processing Record 286| Quatre Cocos
# Processing Record 287| Winnemucca
# Processing Record 288| Shenjiamen
# Processing Record 289| Lahaina
# Processing Record 290| Norman Wells
# Processing Record 291| Porto Velho
# City not found next ...
# Processing Record 292| Harbour Breton
# Processing Record 293| Hofn
# Processing Record 294| Katobu
# Processing Record 295| Ribnitz-Damgarten
# Processing Record 296| Goderich
# Processing Record 297| Dhule
# Processing Record 298| Grand-Santi
# Processing Record 299| Lima
# Processing Record 300| Borsec
# Processing Record 301| Sabang
# Processing Record 302| Lorengau
# Processing Record 303| Tumarbong
# Processing Record 304| La Paz
# Processing Record 305| San Policarpo
# Processing Record 306| Kuching
# Processing Record 307| Port Blair
# Processing Record 308| Port Macquarie
# Processing Record 309| Klaksvík
# Processing Record 310| Vao
# Processing Record 311| Pauini
# Processing Record 312| Valdivia
# City not found next ...
# Processing Record 313| Mbale
# Processing Record 314| Raudeberg
# Processing Record 315| Verkhnyaya Toyma
# Processing Record 316| Lamar
# Processing Record 317| Semut
# Processing Record 318| Antalaha
# Processing Record 319| Baykit
# Processing Record 320| Rockhampton
# Processing Record 321| Saint George
# Processing Record 322| Baruun-Urt
# City not found next ...
# Processing Record 323| Exeter
# Processing Record 324| Shimoda
# Processing Record 325| Lagoa
# Processing Record 326| Homer
# Processing Record 327| Mount Gambier
# Processing Record 328| Ancud
# Processing Record 329| Huron
# Processing Record 330| Brønnøysund
# Processing Record 331| Tambacounda
# Processing Record 332| Cotacachi
# Processing Record 333| Vilhena
# Processing Record 334| Aykhal
# Processing Record 335| Hirado
# Processing Record 336| Naica
# Processing Record 337| Price
# Processing Record 338| Paharpur
# Processing Record 339| Saint-Augustin
# Processing Record 340| Mutoko
# Processing Record 341| Constitución
# Processing Record 342| Płock
# Processing Record 343| Waverly
# Processing Record 344| Fort Nelson
# Processing Record 345| San Miguel de Cozumel
# Processing Record 346| Pokhara
# City not found next ...
# Processing Record 347| De Panne
# Processing Record 348| Poum
# Processing Record 349| Koumra
# Processing Record 350| Bull Savanna
# Processing Record 351| Chernyshevskiy
# Processing Record 352| Setermoen
# Processing Record 353| Kavaratti
# Processing Record 354| Vangaindrano
# Processing Record 355| Ust'-Uda
# Processing Record 356| Xiuyan
# City not found next ...
# Processing Record 357| Pecos
# Processing Record 358| Sørland
# Processing Record 359| Verkhoyansk
# Processing Record 360| Pisco
# City not found next ...
# Processing Record 361| Noumea
# Processing Record 362| Lakatoro
# Processing Record 363| Padang
# Processing Record 364| Te Anau
# Processing Record 365| Maniitsoq
# Processing Record 366| Abalak
# Processing Record 367| Haridwar
# Processing Record 368| Ishnya
# Processing Record 369| Sibu
# Processing Record 370| Shimanovsk
# City not found next ...
# Processing Record 371| Isla Vista
# Processing Record 372| Qarchī Gak
# Processing Record 373| Chihuahua
# Processing Record 374| Springfield
# Processing Record 375| Caravelas
# City not found next ...
# Processing Record 376| Nyurba
# Processing Record 377| Nadvoitsy
# Processing Record 378| Leningradskiy
# Processing Record 379| Mormugao
# City not found next ...
# Processing Record 380| Provideniya
# Processing Record 381| Boddam
# City not found next ...
# Processing Record 382| Umm Bāb
# City not found next ...
# Processing Record 383| Shīeli
# Processing Record 384| Hualmay
# Processing Record 385| Meadow Lake
# Processing Record 386| Teshie
# Processing Record 387| Khanbari
# City not found next ...
# Processing Record 388| Tiznit Province
# Processing Record 389| Suriāpet
# Processing Record 390| Zunyi
# Processing Record 391| Vestmannaeyjar

# %% [markdown]
# # Convert Raw Data to DataFrame¶
# #Export the city data into a .csv.
# #Display the DataFrame

# %%
weather_df = pd.DataFrame({"City":city_name, "Latitude":latitude, "Longitude":longitude,
    "Maximum Temperature": max_temperature,"Humidity %":humidity, "Cloudiness %": cloudiness
   ,"Wind Speed(mph)": wind_speed,"Country":country,"Date":date})

weather_df
# Out:
#                City  Latitude  Longitude  Maximum Temperature  Humidity %  \
# 0             Ancud    -41.87     -73.82                13.00          62
# 1           Ushuaia    -54.80     -68.30                14.00          47
# 2          Hermanus    -34.42      19.23                13.89          86
# 3    Ribeira Grande     38.52     -28.70                16.36          72
# 4       Forestville     38.85     -76.88                17.22          81
# ..              ...       ...        ...                  ...         ...
# 564           Wendo      6.60      38.42                14.37          87
# 565     Pundaguitan      6.37     126.17                27.90          76
# 566         Aquiraz     -3.90     -38.39                27.00          78
# 567   Makakilo City     21.35    -158.09                31.00          55
# 568        Sisimiut     66.94     -53.67                -9.82          84
#
#      Cloudiness %  Wind Speed(mph) Country                Date
# 0               5             5.70      CL 2020-11-08 00:47:51
# 1              40             9.30      AR 2020-11-08 00:47:38
# 2              91             2.24      ZA 2020-11-08 00:47:59
# 3               8             5.96      PT 2020-11-08 00:43:56
# 4               1             1.50      US 2020-11-08 00:47:59
# ..            ...              ...     ...                 ...
# 564            81             1.61      ET 2020-11-08 00:51:06
# 565            56             2.13      PH 2020-11-08 00:51:06
# 566            20             3.60      BR 2020-11-08 00:51:05
# 567            40             3.10      US 2020-11-08 00:51:06
# 568            51             4.98      GL 2020-11-08 00:47:59
#
# [569 rows x 9 columns]

# %%
# Output File (CSV)
output_data_file = "output_data/cities.csv"
weather_df.to_csv(output_data_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-b39bda3d0142> in <module>
#       1 # Output File (CSV)
#       2 output_data_file = "../../output_data/cities.csv"
# ----> 3 weather_df.to_csv(output_data_file)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     182             close = False
#     183         else:
# --> 184             f, handles = get_handle(
#     185                 self.path_or_buf,
#     186                 self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../output_data/cities.csv'

# %% [markdown]
# # Inspect the data and remove the cities where the humidity > 100%.¶
# # Skip this step if there are no cities that have humidity > 100%.

# %%
weather_humidity_inspected = weather_df.loc[weather_df["Humidity %"] <= 100 , :]
weather_humidity_inspected

# %%
#  Get the indices of cities that have humidity over 100%.
weather_high_humidity = weather_df.loc[weather_df["Humidity %"] > 100 , :]
indices_high_humidity = weather_high_humidity.index.values
print(indices_high_humidity)

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
weather_df.drop (indices_high_humidity, inplace=True)
weather_df

# %% [markdown]
# # Plotting the Data¶
# #Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# #Save the plotted figures as .pngs

# %% [markdown]
# # Latitude vs. Temperature Plot

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties
from datetime import datetime
plt.scatter(weather_df["Latitude"],weather_df["Maximum Temperature"], facecolors="red", marker="o", edgecolor="black")
plt.title(f"Latitude vs. Temperature on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/City_Latitude_vs_Max_Temperature.png")

plt.show()

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

plt.scatter(weather_df["Latitude"],weather_df["Humidity %"],facecolors="blue", marker="o", edgecolor="black")
plt.title(f"Latitude vs. Humidity on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Humididty")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/City_Latitude_vs_Humidity.png")


plt.show()

# %% [markdown]
# # Latitude vs. Cloudiness Plot

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

plt.scatter(weather_df["Latitude"],weather_df["Cloudiness %"],facecolors="green", marker="o", edgecolor="black")
plt.title(f"Latitude vs. Cloudiness on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)
# Save Figure
plt.savefig("../output_data/City_Latitude_vs_Cloudiness.png")


plt.show()

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

plt.scatter(weather_df["Latitude"],weather_df["Wind Speed(mph)"],facecolors="purple", marker="o", edgecolor="black")
plt.title(f"Latitude vs. Wind Speed on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/City_Latitude_vs_Wind_Speed.png")


plt.show()

# %% [markdown]
# # Linear Regression

# %% [markdown]
# # Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

#Extraction of Northern Hemisphere Data
northern_hemisphere = weather_df.loc[weather_df["Latitude"]>0]
x_values = northern_hemisphere["Latitude"]
y_values = northern_hemisphere["Maximum Temperature"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")
plt.title(f"Northern Hemisphere Max Temp vs. Latitude Linear Regression on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperaure (C)")
plt.grid(True)


# Save Figure
plt.savefig("../output_data/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

print(line_eq)
plt.show()

# %% [markdown]
# # Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

#Extraction of Northern Hemisphere Data
southern_hemisphere = weather_df.loc[weather_df["Latitude"]<0]
x_values = southern_hemisphere["Latitude"]
y_values = southern_hemisphere["Maximum Temperature"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")
plt.title(f"Southern Hemisphere - Max Temp vs. Latitude Linear Regression on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperaure (C)")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")


print(line_eq)
plt.show()

# %% [markdown]
# # Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

y_values = northern_hemisphere["Humidity %"]
x_values =  northern_hemisphere["Latitude"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")
plt.title(f"Northern Hemisphere Humidity (%) vs. Latitude Linear Regression on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")

print(line_eq)
plt.show()

# %% [markdown]
# # Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

y_values = southern_hemisphere["Humidity %"]
x_values =  southern_hemisphere["Latitude"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")
plt.title(f"Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")

print(line_eq)
plt.show()

# %% [markdown]
# # Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

y_values = northern_hemisphere["Cloudiness %"]
x_values =  northern_hemisphere["Latitude"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")
plt.title(f"Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")

print(line_eq)
plt.show()

# %% [markdown]
# # Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

y_values = southern_hemisphere["Cloudiness %"]
x_values = southern_hemisphere["Latitude"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")


plt.title(f"Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")

print(line_eq)
plt.show()

# %% [markdown]
# # Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_values = northern_hemisphere["Wind Speed(mph)"]
x_values = northern_hemisphere["Latitude"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")


plt.title(f"Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/Northern Hemisphere - WindSpeed(mph)) vs. Latitude Linear Regression.png")

print(line_eq)
plt.show()

# %% [markdown]
# # Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_values = southern_hemisphere["Wind Speed(mph)"]
x_values = southern_hemisphere["Latitude"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")


plt.title(f"Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression  on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/Southern Hemisphere - WindSpeed(mph)) vs. Latitude Linear Regression.png")

print(line_eq)
plt.show()
